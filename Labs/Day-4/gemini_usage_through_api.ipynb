# %%
"""Use Gemini API with prompts."""
# If you do not have the `google-genai` package installed, you can install it using:
# pip install -q -U google-genai
from google import genai

my_api_key = "AIzaSyBa2Io2k9FnhXo14VBCTqy8DIWY3ohbDxM"
client = genai.Client(api_key=my_api_key)

response = client.models.generate_content(
    model="gemini-2.0-flash", contents="Explain how AI works in a few words"
)
print(response.text)
"""
Output:
AI learns from data to make predictions or decisions.
"""
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[1], line 9
#       6 my_api_key = "AIzaSyBa2Io2k9FnhXo14VBCTqy8DIWY3ohbDxM"
#       7 client = genai.Client(api_key=my_api_key)
# ----> 9 response = client.models.generate_content(
#      10     model="gemini-2.0-flash", contents="Explain how AI works in a few words"
#      11 )
#      12 print(response.text)
#      13 """
#      14 Output:
#      15 AI learns from data to make predictions or decisions.
#      16 """
#
# File /data/miniconda/envs/my_env/lib/python3.12/site-packages/google/genai/models.py:5778, in Models.generate_content(self, model, contents, config)
#    5776 while remaining_remote_calls_afc > 0:
#    5777   i += 1
# -> 5778   response = self._generate_content(
#    5779       model=model, contents=contents, config=parsed_config
#    5780   )
#    5781   logger.info(f'AFC remote call {i} is done.')
# ...
